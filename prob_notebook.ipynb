# %% [markdown]
# <a href="https://colab.research.google.com/github/nisssrinebenalal-rgb/proba_project/blob/notebook/prob_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# proba project    GJHIOOLM

# %% [markdown]
# # prob
